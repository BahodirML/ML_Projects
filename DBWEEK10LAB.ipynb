# %% [markdown]
# <a href="https://colab.research.google.com/github/Bahodir011/Bahodir011/blob/main/DBWEEK10LAB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 새 섹션

# %%
from sqlalchemy import create_engine
my_conn = create_engine("sqlite:////content/my_db.db")

# %%
from sqlalchemy.exc import SQLAlchemyError
q="SELECT * FROM student WHERE mark BETWEEN 65 AND 75"
try:
  r_set=my_conn.execute(q)  
  r_list=r_set.fetchall()
  for row in r_list:
    print(row)
except SQLAlchemyError as e:
  error=str(e.__dict__['orig'])
  print(error)
else:
  print("Total Number of rows : ",len(r_list))
# Out:
# no such table: student

# %%
from sqlalchemy.exc import SQLAlchemyError
my_tuple=(65,75)
q="SELECT * FROM student WHERE mark BETWEEN ? AND ?"
try:
  r_set=my_conn.execute(q,my_tuple)  
  r_list=r_set.fetchall()
  for row in r_list:
    print(row)
except SQLAlchemyError as e:
  error=str(e.__dict__['orig'])
  print(error)
else:
  print("Total Number of rows : ",len(r_list))
# Out:
# no such table: student

# %%
from sqlalchemy.exc import SQLAlchemyError
my_tuple=(25,90)
q="SELECT * FROM student WHERE mark NOT BETWEEN ? AND ?"
try:
  r_set=my_conn.execute(q,my_tuple)  
  r_list=r_set.fetchall()
  for row in r_list:
    print(row)
except SQLAlchemyError as e:
  error=str(e.__dict__['orig'])
  print(error)
else:
  print("Total Number of rows : ",len(r_list))
# Out:
# no such table: student

# %%
from sqlalchemy.exc import SQLAlchemyError
my_tuple=(25,90)
q="SELECT * FROM student WHERE mark NOT BETWEEN ? AND ?"
try:
  r_set=my_conn.execute(q,my_tuple)  
  r_list=r_set.fetchall()
  for row in r_list:
    print(row)
except SQLAlchemyError as e:
  error=str(e.__dict__['orig'])
  print(error)
else:
  print("Total Number of rows : ",len(r_list))
# Out:
# no such table: student

# %%
from sqlalchemy.exc import SQLAlchemyError
q="SELECT * FROM student ORDER BY class,mark DESC"
try:
  r_set=my_conn.execute(q)  
  r_list=r_set.fetchall()
  for rows in r_list:
    print(rows)
except SQLAlchemyError as e:
  error=str(e.__dict__['orig'])
  print(error)
else:
  print("Total Number of rows : ",len(r_list))
# Out:
# no such table: student

# %%
from sqlalchemy.exc import SQLAlchemyError
q="SELECT * FROM student WHERE class='Five' ORDER BY mark DESC"
try:
  r_set=my_conn.execute(q)  
  r_list=r_set.fetchall()
  for rows in r_list:
    print(rows)
except SQLAlchemyError as e:
  error=str(e.__dict__['orig'])
  print(error)
else:
  print("Total Number of rows : ",len(r_list))
# Out:
# no such table: student

# %%
from sqlalchemy.exc import SQLAlchemyError
q="SELECT * FROM student WHERE class='Five' ORDER BY mark DESC LIMIT 1,1"
try:
  r_set=my_conn.execute(q)  
  r_list=r_set.fetchall()
  for rows in r_list:
    print(rows)
except SQLAlchemyError as e:
  error=str(e.__dict__['orig'])
  print(error)
else:
  print("Total Number of rows : ",len(r_list))
# Out:
# no such table: student

# %%
import sqlite3
from employee import Employee

conn = sqlite3.connect(':memory:')

c = conn.cursor()

c.execute("""CREATE TABLE employees (
            first text,
            last text,
            pay integer
            )""")


def insert_emp(emp):
    with conn:
        c.execute("INSERT INTO employees VALUES (:first, :last, :pay)", {'first': emp.first, 'last': emp.last, 'pay': emp.pay})


def get_emps_by_name(lastname):
    c.execute("SELECT * FROM employees WHERE last=:last", {'last': lastname})
    return c.fetchall()


def update_pay(emp, pay):
    with conn:
        c.execute("""UPDATE employees SET pay = :pay
                    WHERE first = :first AND last = :last""",
                  {'first': emp.first, 'last': emp.last, 'pay': pay})


def remove_emp(emp):
    with conn:
        c.execute("DELETE from employees WHERE first = :first AND last = :last",
                  {'first': emp.first, 'last': emp.last})

emp_1 = Employee('John', 'Doe', 80000)
emp_2 = Employee('Jane', 'Doe', 90000)

insert_emp(emp_1)
insert_emp(emp_2)

emps = get_emps_by_name('Doe')
print(emps)

update_pay(emp_2, 95000)
remove_emp(emp_1)

emps = get_emps_by_name('Doe')
print(emps)

conn.close()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-10-4d388fea799f> in <module>
#       1 import sqlite3
# ----> 2 from employee import Employee
#       3
#       4 conn = sqlite3.connect(':memory:')
#       5
#
# ModuleNotFoundError: No module named 'employee'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
